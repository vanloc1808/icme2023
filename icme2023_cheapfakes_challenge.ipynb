# %% [markdown]
# ## Install environment

# %%
# !rm -rf icme2023
# !git clone https://github.com/thanhson28/icme2023.git
# %cd icme2023
# !rm -r detectron2
# !git clone https://github.com/facebookresearch/detectron2.git
# !scp -r /content/icme2023/detectron2_changes/* /content/icme2023/detectron2/detectron2
# %cd /content/icme2023/detectron2/
# !pip install -e ./
# %cd ..
# !pip install pyyaml==5.1
# !pip install ipdb
# %cd /content/drive/MyDrive/cosmos/COSMOS
# !python -m spacy download en_core_web_sm
# !pip install tqdm
# !pip install -U sentence-transformers
# !pip install selenium webdriver_manager
# %cd /content/icme2023/grit
# !pip install -r requirements.txt
# !python -m spacy download en
# %cd models/ops/
# !python setup.py build develop
# !python test.py
#Download checkpoint
# %cd /content/icme2023/grit
# !gdown 1WLsMrtVFTftSJiGHg7iALNFImtefHtOT
# !mkdir /content/icme2023/models_final
#download and locate pretrained to models_final/img_use_rcnn_margin_10boxes_jitter_rotate_aug_ner.pt
# !wget https://dl.google.com/linux/direct/google-chrome-stable_current_amd64.deb
# !apt-get install -y libu2f-udev xorg xvfb gtk2-engines-pixbuf dbus-x11 xfonts-base xfonts-100dpi xfonts-75dpi xfonts-cyrillic xfonts-scalable
# !dpkg -i google-chrome-stable_current_amd64.deb
# Out:
# Cloning into 'icme2023'...
# remote: Enumerating objects: 283, done.
# remote: Counting objects: 100% (62/62), done.
# remote: Compressing objects: 100% (53/53), done.
# remote: Total 283 (delta 27), reused 24 (delta 7), pack-reused 221
# Receiving objects: 100% (283/283), 85.40 MiB | 38.63 MiB/s, done.
# Resolving deltas: 100% (41/41), done.
# /content/icme2023
# rm: cannot remove 'detectron2': No such file or directory
# Cloning into 'detectron2'...
# remote: Enumerating objects: 14940, done.
# remote: Counting objects: 100% (25/25), done.
# remote: Compressing objects: 100% (22/22), done.
# remote: Total 14940 (delta 9), reused 15 (delta 3), pack-reused 14915
# Receiving objects: 100% (14940/14940), 6.06 MiB | 27.83 MiB/s, done.
# Resolving deltas: 100% (10830/10830), done.
# /content/icme2023/detectron2
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Obtaining file:///content/icme2023/detectron2
# ...

# %% [markdown]
# ## Change INPUT_FOLDER

# %% [markdown]
# ### INPUT_FOLDER structure:
# - INPUT_FOLDER should has structure as same as requirement of organizer, contain "test.json" as follow:\
# INPUT_FOLDER \
# ├── test.json \
# ├── public_test_mmsys \
# │   ├── 0.jpg \
# │   ├── 100.png \
# │   ├── 101.jpg \
# │   ├── 102.jpg \
# - With "public_test_mmsys/0.jpg" is an "img_local_path" in "test.json" for example.

# %%
# %env INPUT_FOLDER=/content/drive/MyDrive/cosmos/data/acm
# Out:
# env: INPUT_FOLDER=/content/drive/MyDrive/cosmos/data/acm

# %% [markdown]
# ## Run experiments for Task 1 of Cheapfakes detection

# %% [markdown]
# ### Original cosmos

# %%
# %cd /content/icme2023/
# %env PYTHONPATH=$PYTHONPATH:./grit
# !python /content/icme2023/evaluate_ooc_original_cosmos.py
# Out:
# /content/icme2023
# env: PYTHONPATH=$PYTHONPATH:./grit
# 2023-03-27 14:30:45.747079: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-27 14:30:46.728401: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/lib/python3.9/dist-packages/cv2/../../lib64:/usr/lib64-nvidia
# ...

# %% [markdown]
# ### Method 1

# %%
# %cd /content/icme2023/
# %env PYTHONPATH=$PYTHONPATH:./grit
# !python /content/icme2023/evaluate_ooc_method_1.py
# Out:
# 2023-03-27 12:57:51.895756: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-27 12:57:52.936655: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/lib/python3.9/dist-packages/cv2/../../lib64:/usr/lib64-nvidia
# ...

# %% [markdown]
# ### Method 2

# %%
# %cd /content/icme2023/
# %env PYTHONPATH=$PYTHONPATH:./grit
# !python /content/icme2023/evaluate_ooc_method_2.py
# Out:
# 2023-03-27 13:09:10.961860: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-27 13:09:12.088078: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/lib/python3.9/dist-packages/cv2/../../lib64:/usr/lib64-nvidia
# ...

# %% [markdown]
# ### Method 1 + Method 2

# %%
# %cd /content/icme2023/
# %env PYTHONPATH=$PYTHONPATH:./grit
# !python /content/icme2023/evaluate_ooc.py
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# /content/icme2023
# env: PYTHONPATH=$PYTHONPATH:./grit
# 2023-03-27 12:09:17.086428: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-27 12:09:18.172429: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/lib/python3.9/dist-packages/cv2/../../lib64:/usr/lib64-nvidia
# ...
